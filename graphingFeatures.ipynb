# %%
import pandas as pd
from ggplot import *

# %%
byRepo = pd.read_csv('data/intermediate/byRepo.csv')
del byRepo['Unnamed: 0']
byRepo.shape
# Out:
# (1812, 7)

# %%
byRepo.head()
# Out:
#                      full_name  daysSinceCreation language  futureCommits_num  \
# 0         R-Finance/quantstrat               -127        R                 13
# 1                gagolews/Rpkg               -123        R                180
# 2              cxxr-devel/cxxr               -120        R                 10
# 3  rasmusab/bayesian_first_aid                 34        R                 38
# 4              mages/googleVis                 -2        R                106
#
#    pastCommits_num  daysSinceLastCommit  daysSinceFirstCommit
# 0              562                   27                  1469
# 1               57                    6                   139
# 2               36                   34                    90
# 3               41                    6                   202
# 4               32                    6                     6

# %%
byRepo['aliveOrDead'] = np.where(byRepo['futureCommits_num'] > 0,
                                 'alive',
                                 'dead')

# %%
byRepo.head()
# Out:
#                      full_name  daysSinceCreation language  futureCommits_num  \
# 0         R-Finance/quantstrat               -127        R                 13
# 1                gagolews/Rpkg               -123        R                180
# 2              cxxr-devel/cxxr               -120        R                 10
# 3  rasmusab/bayesian_first_aid                 34        R                 38
# 4              mages/googleVis                 -2        R                106
#
#    pastCommits_num  daysSinceLastCommit  daysSinceFirstCommit aliveOrDead
# 0              562                   27                  1469       alive
# 1               57                    6                   139       alive
# 2               36                   34                    90       alive
# 3               41                    6                   202       alive
# 4               32                    6                     6       alive

# %%
byRepo['aliveOrDead'].value_counts()
# Out:
# dead     1098
# alive     714
# dtype: int64

# %%
q = ggplot(byRepo, aes(x='daysSinceLastCommit'))
q += geom_bar(binwidth=14)
q += ylab('number of repos')
q += facet_wrap('aliveOrDead')
print q
# Out:
# <ggplot: (282049677)>

# %%
byRepo['log10(PastCommits + 1)'] = np.log10(byRepo['pastCommits_num']+1)
q = ggplot(byRepo, aes(x='log10(PastCommits + 1)'))
q += geom_bar()
q += ylab('number of repos')
q += facet_wrap('aliveOrDead')
print q
# Out:
# <ggplot: (282057401)>

# %%
q = ggplot(byRepo, aes(x='daysSinceCreation', 
                       y='daysSinceLastCommit'))
q += geom_point()
q += facet_wrap('aliveOrDead')
print q
# Out:
# <ggplot: (281755145)>

# %%
byRepo[byRepo['daysSinceCreation'] < 0].head()
# Out:
#                full_name  daysSinceCreation language  futureCommits_num  \
# 0   R-Finance/quantstrat               -127        R                 13
# 1          gagolews/Rpkg               -123        R                180
# 2        cxxr-devel/cxxr               -120        R                 10
# 4        mages/googleVis                 -2        R                106
# 23   mwpennell/geiger-v2                -16        R                 37
#
#     pastCommits_num  daysSinceLastCommit  daysSinceFirstCommit aliveOrDead  \
# 0               562                   27                  1469       alive
# 1                57                    6                   139       alive
# 2                36                   34                    90       alive
# 4                32                    6                     6       alive
# 23              125                    6                   629       alive
#
#     log10(PastCommits + 1)
# 0                 2.750508
# 1                 1.763428
# 2                 1.568202
# 4                 1.518514
# 23                2.100371

# %%
q = ggplot(byRepo, aes(x='daysSinceFirstCommit', 
                       y='daysSinceLastCommit'))
q += geom_point()
q += facet_wrap('aliveOrDead')
print q
# Out:
# <ggplot: (281763737)>

# %%
byRepo[byRepo['daysSinceFirstCommit'] > 4000]
# Out:
#          full_name  daysSinceCreation language  futureCommits_num  \
# 1451  earl/vanilla               1663        R                  0
#
#       pastCommits_num  daysSinceLastCommit  daysSinceFirstCommit aliveOrDead  \
# 1451               67                 1378                  5025        dead
#
#       log10(PastCommits + 1)
# 1451                1.832509

# %%
byRepo.head()
