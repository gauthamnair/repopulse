# %%
from sklearn import linear_model
import sklearn.cross_validation
import sklearn.metrics
import sklearn.ensemble
import sklearn.preprocessing
import sklearn.pipeline
import modelTools
import trainingData
import numpy as np
import pandas as pd

# %%
byRepo = trainingData.load()
modelTools.addAliveOrDeadColumn(byRepo)
y = modelTools.makeTarget(byRepo)
allColumns = modelTools._predColumns

# %%
def evaluatePredictors(predColumns = allColumns):
	learner = sklearn.pipeline.Pipeline(
		[('scaler', sklearn.preprocessing.StandardScaler()),
		('logistic', linear_model.LogisticRegression())]) 

	(X, colNames) = modelTools.makePredictors(byRepo, predColumns = predColumns)

	evaluateModel = modelTools.makeModelEvaluator(X, y)
	report = evaluateModel(learner)

	print report.classification_report()
	print "auc:", report.auc()

	learner.fit(X, y)
	return (learner, colNames, report.auc())

# %%
def effectOfExcludingColumns(toExclude):
    print "excluding ", toExclude, ":"
    (learner, colNames, auc) = evaluatePredictors(predColumns=[p for p in allColumns if p not in toExclude])
    logistic = learner.named_steps['logistic']
    coefs = pd.Series(data=np.concatenate( (logistic.coef_[0], logistic.intercept_) ), 
        index = colNames + ['intercept'])
    coefs.plot(kind='barh')
    plt.title('AUC: '+ str(auc))
    return (coefs, auc)

# %%
print "using all predictors"
(coefs,auc) = effectOfExcludingColumns([])
# Out:
# using all predictors
# excluding  [] :
#              precision    recall  f1-score   support
#
#         0.0       0.82      0.84      0.83     10709
#         1.0       0.79      0.76      0.77      8091
#
# avg / total       0.81      0.81      0.81     18800
# auc: 0.888943236139

# %%
toExclude = ['daysSinceLastCommit']
(coefs,auc) = effectOfExcludingColumns(toExclude)
# Out:
# excluding  ['daysSinceLastCommit'] :
#              precision    recall  f1-score   support
#
#         0.0       0.73      0.94      0.82     10709
#         1.0       0.87      0.55      0.67      8091
#
# avg / total       0.79      0.77      0.76     18800
# auc: 0.847103263317

# %%
toExclude = ['daysSinceLastCommit', 'ewmaTwoWeeks', 'ewmaOneMonth']
(coefs,auc) = effectOfExcludingColumns(toExclude)
# Out:
# excluding  ['daysSinceLastCommit', 'ewmaTwoWeeks', 'ewmaOneMonth'] :
#              precision    recall  f1-score   support
#
#         0.0       0.73      0.93      0.82     10709
#         1.0       0.86      0.54      0.66      8091
#
# avg / total       0.79      0.76      0.75     18800
# auc: 0.842478830569

# %%
toExclude = ['daysSinceLastCommit'] + [x for x in allColumns if x.startswith('ewma')]
(coefs,auc) = effectOfExcludingColumns(toExclude)
# Out:
# excluding  ['daysSinceLastCommit', 'ewmaOneMonth', 'ewmaOneYear', 'ewmaSixMonth', 'ewmaThreeMonth', 'ewmaTwoWeeks'] :
#              precision    recall  f1-score   support
#
#         0.0       0.71      0.84      0.77     10709
#         1.0       0.72      0.54      0.62      8091
#
# avg / total       0.71      0.71      0.70     18800
# auc: 0.764130368584

# %%
toExclude = ['daysSinceLastCommit', 'pastCommits_num'] + [x for x in allColumns if x.startswith('ewma')]
(coefs,auc) = effectOfExcludingColumns(toExclude)
# Out:
# excluding  ['daysSinceLastCommit', 'pastCommits_num', 'ewmaOneMonth', 'ewmaOneYear', 'ewmaSixMonth', 'ewmaThreeMonth', 'ewmaTwoWeeks'] :
#              precision    recall  f1-score   support
#
#         0.0       0.66      0.85      0.74     10709
#         1.0       0.68      0.42      0.52      8091
#
# avg / total       0.67      0.66      0.65     18800
# auc: 0.709239184785
